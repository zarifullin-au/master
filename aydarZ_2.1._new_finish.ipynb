# %% [markdown]
# # Задание 1_Pandas

# %%
import numpy as np
import pandas as pd

# %%
data = {'Surname': ['Ivanov', 'Petrov', 'Sidorov', 'Ivanova', 'Karpov', 'Hill', 'Boni', 'Mitchell', 'Onio', 'Lavrov'],
        'age': [42, 33, 55, np.nan, 65, 23, 25, np.nan, 27, 37],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = [1,2]

# %% [markdown]
# #### 0. Создать датафрейм.

# %%
df1=pd.DataFrame(data)
df1
# Out:
#     Surname   age  visits priority
# 0    Ivanov  42.0       1      yes
# 1    Petrov  33.0       3      yes
# 2   Sidorov  55.0       2       no
# 3   Ivanova   NaN       3      yes
# 4    Karpov  65.0       2       no
# 5      Hill  23.0       3       no
# 6      Boni  25.0       1       no
# 7  Mitchell   NaN       1      yes
# 8      Onio  27.0       2       no
# 9    Lavrov  37.0       1       no

# %% [markdown]
# #### 1. Вывести информацию о датафрейме.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Surname   10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 448.0+ bytes

# %%
df1.describe()
# Out:
#              age     visits
# count   8.000000  10.000000
# mean   38.375000   1.900000
# std    14.994642   0.875595
# min    23.000000   1.000000
# 25%    26.500000   1.000000
# 50%    35.000000   2.000000
# 75%    45.250000   2.750000
# max    65.000000   3.000000

# %% [markdown]
# #### 2. Вернуть первые 3 строки DataFrame `df`.

# %%
df1.head(3)
# Out:
#    Surname   age  visits priority
# 0   Ivanov  42.0       1      yes
# 1   Petrov  33.0       3      yes
# 2  Sidorov  55.0       2       no

# %% [markdown]
# #### 3. Выберите только столбцы 'Surname' и 'age' из DataFrame `df`.

# %%
df1[['Surname','age']]
# Out:
#     Surname   age
# 0    Ivanov  42.0
# 1    Petrov  33.0
# 2   Sidorov  55.0
# 3   Ivanova   NaN
# 4    Karpov  65.0
# 5      Hill  23.0
# 6      Boni  25.0
# 7  Mitchell   NaN
# 8      Onio  27.0
# 9    Lavrov  37.0

# %% [markdown]
# #### 4. Выберите данные в строках `[3, 4, 8]` * и * в столбцах `['Surname', 'age']`.

# %%
df1.loc[[3,4,8],['Surname', 'age']]
# Out:
#    Surname   age
# 3  Ivanova   NaN
# 4   Karpov  65.0
# 8     Onio  27.0

# %% [markdown]
# #### 5. Выберите строки где количество посещений банка больше 3.

# %%
a=df1['visits'] > 3
df1.loc[a]
# Out:
# Empty DataFrame
# Columns: [Surname, age, visits, priority]
# Index: []

# %% [markdown]
# #### 6. Выберите строки, в которых отсутствует возраст.

# %%
b=df1['age'].isnull()
df1.loc[b]
# Out:
#     Surname  age  visits priority
# 3   Ivanova  NaN       3      yes
# 7  Mitchell  NaN       1      yes

# %% [markdown]
# #### 7. Выберите строки, в которых клиент был больше 2х раз в банке * и * возраст составляет более 30 лет.

# %%
c=df1['visits']>2 
d=df1['age']>30
df1.loc[c&d]
# Out:
#   Surname   age  visits priority
# 1  Petrov  33.0       3      yes

# %% [markdown]
# #### 8. Выберите строки в которых возраст от 55 до 65 (включительно).

# %%
e=df1['age']>55
f=df1['age']<=65
df1.loc[e&f]
# Out:
#   Surname   age  visits priority
# 4  Karpov  65.0       2       no

# %% [markdown]
# #### 9. Измените возраст в строке '4' на 44.

# %%
df1.loc[4, 'age']=44
df1
# Out:
#     Surname   age  visits priority
# 0    Ivanov  42.0       1      yes
# 1    Petrov  33.0       3      yes
# 2   Sidorov  55.0       2       no
# 3   Ivanova   NaN       3      yes
# 4    Karpov  44.0       2       no
# 5      Hill  23.0       3       no
# 6      Boni  25.0       1       no
# 7  Mitchell   NaN       1      yes
# 8      Onio  27.0       2       no
# 9    Lavrov  37.0       1       no

# %% [markdown]
# #### 10. Рассчитать общее количество всех посещений.

# %%
df1['visits'].sum()
# Out:
# 19

# %% [markdown]
# #### 11. Расчитайте средний возраст клиентов

# %%
df1.age.mean()
# Out:
# 35.75

# %% [markdown]
# #### 12. Добавьте новую строку `k` к `df` со значениями по вашему желанию. Затем удалите ее.

# %%
df1.loc[len(df1)]=['Kuzmin','29','0','yes']
df1
# Out:
#      Surname  age visits priority
# 0     Ivanov   42      1      yes
# 1     Petrov   33      3      yes
# 2    Sidorov   55      2       no
# 3    Ivanova  NaN      3      yes
# 4     Karpov   44      2       no
# 5       Hill   23      3       no
# 6       Boni   25      1       no
# 7   Mitchell  NaN      1      yes
# 8       Onio   27      2       no
# 9     Lavrov   37      1       no
# 10    Kuzmin   29      0      yes

# %%
import pandas as pd

df2=df1.drop(df1.index[[10]])
df3=pd.DataFrame(df2)
df3
# Out:
#     Surname  age visits priority
# 0    Ivanov   42      1      yes
# 1    Petrov   33      3      yes
# 2   Sidorov   55      2       no
# 3   Ivanova  NaN      3      yes
# 4    Karpov   44      2       no
# 5      Hill   23      3       no
# 6      Boni   25      1       no
# 7  Mitchell  NaN      1      yes
# 8      Onio   27      2       no
# 9    Lavrov   37      1       no

# %% [markdown]
# #### 13. Сортируйте `df` сначала по значениям в 'age' в * возрастающем * порядке, затем по значениям в столбце 'visit' в * возрастающем * порядке.

# %%
df4=df3.sort_values(['age'])
df4
# Out:
#     Surname  age visits priority
# 5      Hill   23      3       no
# 6      Boni   25      1       no
# 8      Onio   27      2       no
# 1    Petrov   33      3      yes
# 9    Lavrov   37      1       no
# 0    Ivanov   42      1      yes
# 4    Karpov   44      2       no
# 2   Sidorov   55      2       no
# 3   Ivanova  NaN      3      yes
# 7  Mitchell  NaN      1      yes

# %%
df5=df3.sort_values(['visits'], ascending=False)
df5
# Out:
#     Surname  age visits priority
# 1    Petrov   33      3      yes
# 3   Ivanova  NaN      3      yes
# 5      Hill   23      3       no
# 2   Sidorov   55      2       no
# 4    Karpov   44      2       no
# 8      Onio   27      2       no
# 0    Ivanov   42      1      yes
# 6      Boni   25      1       no
# 7  Mitchell  NaN      1      yes
# 9    Lavrov   37      1       no

# %% [markdown]
# #### 14. В столбце приоритет замените значения на `Yes` и `No`

# %%
df3.loc[df3['priority'] == 'no','priority'] = 'yes'
df3
# Out:
#     Surname  age visits priority
# 0    Ivanov   42      1      yes
# 1    Petrov   33      3      yes
# 2   Sidorov   55      2      yes
# 3   Ivanova  NaN      3      yes
# 4    Karpov   44      2      yes
# 5      Hill   23      3      yes
# 6      Boni   25      1      yes
# 7  Mitchell  NaN      1      yes
# 8      Onio   27      2      yes
# 9    Lavrov   37      1      yes

# %%
df3.loc[df3['priority'] == 'yes','priority'] = 'no'
df3
# Out:
#     Surname  age visits priority
# 0    Ivanov   42      1       no
# 1    Petrov   33      3       no
# 2   Sidorov   55      2       no
# 3   Ivanova  NaN      3       no
# 4    Karpov   44      2       no
# 5      Hill   23      3       no
# 6      Boni   25      1       no
# 7  Mitchell  NaN      1       no
# 8      Onio   27      2       no
# 9    Lavrov   37      1       no

# %% [markdown]
# #### 15. Предположим, у вас есть DataFrame с 10 столбцами действительных чисел, например:
#
# ```python
# df = pd.DataFrame (np.random.random (size = (5, 10)), columns = список ('abcdefghij'))
# ```
# #### Какой столбец имеет наименьшую сумму? Найдите метку этого столбца.

# %%
import numpy as np
df = pd.DataFrame (np.random.random (size = (5, 10)), columns = list('abcdefghij'))
df
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.905992  0.067703  0.629214  0.684209  0.533637  0.240598  0.889388
# 1  0.434088  0.656085  0.314034  0.839916  0.356972  0.102704  0.682274
# 2  0.694188  0.516385  0.734547  0.417092  0.586224  0.596407  0.566476
# 3  0.370246  0.430192  0.688615  0.942389  0.397159  0.531045  0.312791
# 4  0.075617  0.621049  0.000012  0.471241  0.351901  0.249737  0.924667
#
#           h         i         j
# 0  0.695430  0.025157  0.134666
# 1  0.845415  0.034795  0.068027
# 2  0.697806  0.278649  0.329305
# 3  0.203183  0.576107  0.110910
# 4  0.288984  0.269214  0.141459

# %%
a=df.sum()
pd.DataFrame(a)
# Out:
#           0
# a  2.480131
# b  2.291415
# c  2.366422
# d  3.354847
# e  2.225893
# f  1.720491
# g  3.375597
# h  2.730818
# i  1.183920
# j  0.784367

# %%
g=a.min()
g
# Out:
# 0.7843670447515789

# %%
c=pd.DataFrame(a)
b=a.min()

for i in range(len(a)):
    if b == a[i]:
        print(i)
        break
# Out:
# 9

# %%
pd.DataFrame(a).index[9]
# Out:
# 'j'

# %% [markdown]
# #### 16. Замените все пропущенные значения, на среднее по столбцу
# ```python
# df = pd.DataFrame({'group': list('aabbabbbabab'),
#                        'value': [1, 2, 3, np.nan, 2, 3,
#                                  np.nan, 1, 7, 3, np.nan, 8]})
# ```

# %%
df = pd.DataFrame({'group': list('aabbabbbabab'),
                       'value': [1, 2, 3, np.nan, 2, 3, 
                                 np.nan, 1, 7, 3, np.nan, 8]})
pd.DataFrame(df)
# Out:
#    group  value
# 0      a    1.0
# 1      a    2.0
# 2      b    3.0
# 3      b    NaN
# 4      a    2.0
# 5      b    3.0
# 6      b    NaN
# 7      b    1.0
# 8      a    7.0
# 9      b    3.0
# 10     a    NaN
# 11     b    8.0

# %%
df.fillna(df['value'].mean())
# Out:
#    group     value
# 0      a  1.000000
# 1      a  2.000000
# 2      b  3.000000
# 3      b  3.333333
# 4      a  2.000000
# 5      b  3.000000
# 6      b  3.333333
# 7      b  1.000000
# 8      a  7.000000
# 9      b  3.000000
# 10     a  3.333333
# 11     b  8.000000

# %% [markdown]
# #### 17. Создайте два новых столбца, для From и To. Приведите названия городов к нормальному виду.
#
# ```python
# df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm',
#                                'Budapest_PaRis', 'Brussels_londOn'],
#               'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
#               'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
#                    'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
#                                '12. Air France', '"Swiss Air"']})
# ```

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm', 
                               'Budapest_PaRis', 'Brussels_londOn'],
              'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
              'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
                   'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )', 
                               '12. Air France', '"Swiss Air"']})
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
new_df=df['From_To'].str.split('_', expand=True)
new_df
# Out:
#           0          1
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
new_df.columns=['From','To']
new_df
# Out:
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
final_df=pd.concat([df,new_df],axis=1)
final_df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"
#
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
a=final_df.drop('From_To', axis=1)
pd.DataFrame(a)
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0       10045.0      [23, 47]               KLM(!)    LoNDon      paris
# 1           NaN            []    <Air France> (12)    MAdrid      miLAN
# 2       10065.0  [24, 43, 87]  (British Airways. )    londON  StockhOlm
# 3           NaN          [13]       12. Air France  Budapest      PaRis
# 4       10085.0      [67, 32]          "Swiss Air"  Brussels     londOn

# %% [markdown]
# #### 23. Загрузить свою таблицу данных(из реферата, курсовой, из сайта статистических данных).
#
# Выполните действия с таблицей:
#
# Загрузите таблицу из файла и сохраните ее в переменную df. Используйте функцию read_
#
# Выведите общую информацию по таблице: число строк и столбцов, типы данных в таблице.
#
# Есть ли в таблице пропущенные значения?
#
# Если в таблице есть строки с пропущенными значениями, удалите их.
#
# Сохраните изменения в df.
#
# Выведите на экран описательные статистики по всем количественным переменным в таблице.
#
# Выберите какой-нибудь интересующий вас столбец и проинтерпретируйте описательные статистики по нему (т.е. опишите «обычными» словами, что значат значения типа min, std, 50% и так далее).
#
#
# Переименуйте какие-нибудь столбцы в таблице (хотя бы один, можно несколько) и сохраните изменения в df.
#
# Добавьте новые столбцы.

# %%
df=pd.read_csv(r'C:\works2\DataFile.csv', encoding='cp1251')
df.head()
# Out:
#                                  Полное наименование Сокращенное наименование  \
# 0  Государственное бюджетное учреждение Ростовско...        ГБУ РО «СШОР № 1»
# 1  Государственное бюджетное учреждение Ростовско...        ГБУ РО «СШОР № 3»
# 2  Государственное бюджетное учреждение Ростовско...        ГБУ РО «СШОР № 5»
# 3  Государственное бюджетное учреждение Ростовско...        ГБУ РО «СШОР № 6»
# 4  Государственное бюджетное учреждение Ростовско...        ГБУ РО «СШОР № 8»
#
#                                                Адрес          Телефон  \
# 0    344113, г. Ростов-на-Дону, ул. Шеболдаева, 97/2  (863) 219-84-27
# 1  347922 , Ростовская область , г. Таганрог, ул....   (8634)38-39-17
# 2       344002, г. Ростов-на-Дону, ул. Пойменная, 2а   (863)282-83-65
# 3  344000, г. Ростов-на-Дону, Пр.Коммунистический...   (863)210-35-69
# 4  344029, г. Ростов-на-Дону, ул.1-й Конной Армии...   (863)242-29-77
#
#               Факс                    Сайт  \
# 0  (863) 219-84-27            schor1-rr.ru
# 1   (8634)36-10-91            www.tcs-3.ru
# 2   (863)282-83-65  www.rowingdon.narod.ru
# 3   (863)210-35-69    www.sportschool-6.ru
# 4   (863)242-29-77         www.sdushor8.ru
#
#                                          Виды спорта
# 0                                       Дзюдо, самбо
# 1  Гребля на байдарках и каноэ, дзюдо, парусный с...
# 2  Гребной спорт (академическая гребля), гребля н...
# 3                Фигурное катание на коньках, хоккей
# 4  Гребной спорт (академическая гребля), легкая а...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Полное наименование       23 non-null     object
#  1   Сокращенное наименование  23 non-null     object
#  2   Адрес                     23 non-null     object
#  3   Телефон                   23 non-null     object
#  4   Факс                      20 non-null     object
#  5   Сайт                      23 non-null     object
#  6   Виды спорта               23 non-null     object
# dtypes: object(7)
# memory usage: 1.4+ KB

# %%
pd.isnull(df)
# Out:
#     Полное наименование  Сокращенное наименование  Адрес  Телефон   Факс  \
# 0                 False                     False  False    False  False
# 1                 False                     False  False    False  False
# 2                 False                     False  False    False  False
# 3                 False                     False  False    False  False
# 4                 False                     False  False    False  False
# 5                 False                     False  False    False  False
# 6                 False                     False  False    False  False
# 7                 False                     False  False    False   True
# 8                 False                     False  False    False  False
# 9                 False                     False  False    False  False
# 10                False                     False  False    False  False
# 11                False                     False  False    False  False
# 12                False                     False  False    False  False
# 13                False                     False  False    False  False
# 14                False                     False  False    False  False
# 15                False                     False  False    False  False
# 16                False                     False  False    False  False
# 17                False                     False  False    False  False
# 18                False                     False  False    False  False
# 19                False                     False  False    False  False
# 20                False                     False  False    False  False
# 21                False                     False  False    False   True
# 22                False                     False  False    False   True
#
#      Сайт  Виды спорта
# 0   False        False
# 1   False        False
# 2   False        False
# 3   False        False
# 4   False        False
# 5   False        False
# 6   False        False
# 7   False        False
# 8   False        False
# 9   False        False
# 10  False        False
# 11  False        False
# 12  False        False
# 13  False        False
# 14  False        False
# 15  False        False
# 16  False        False
# 17  False        False
# 18  False        False
# 19  False        False
# 20  False        False
# 21  False        False
# 22  False        False

# %%
df.describe(include='all')
# Out:
#                                       Полное наименование  \
# count                                                  23
# unique                                                 23
# top     Государственное бюджетное учреждение Ростовско...
# freq                                                    1
#
#        Сокращенное наименование  \
# count                        23
# unique                       23
# top           ГБУ РО «СШОР № 1»
# freq                          1
#
#                                                     Адрес         Телефон  \
# count                                                  23              23
# unique                                                 22              23
# top     344022, г. Ростов-на-Дону, ул. Большая Садовая...  (863)276-02-42
# freq                                                    2               1
#
#                   Факс                  Сайт  \
# count               20                    23
# unique              20                    23
# top     (863)276-02-42  www.sportschool-6.ru
# freq                 1                     1
#
#                                               Виды спорта
# count                                                  23
# unique                                                 23
# top     Хоккей на траве (юноши), спортивная борьба (гр...
# freq                                                    1

# %% [markdown]
#  В моей таблице отсутствуют значения $min, std, 50 $%  Однако, возвращены такие значения, как  $количество$ $значений$, $уникальные$ $значения$, $вершина$ $и$ $частота$ $появления$.
#
#  Для числовых значений описываются число $непропущенных$ $значений$, $среднее$, $стандартное$ $отклонение$, $минимальное$ $и$ $максимальное$ $значение$, $медиана$, $0.25$ и $0.75$ $квартили$.

# %%
df.rename(columns={'Виды спорта':'Наименование видов спорта'}, inplace=True)
df.head()
# Out:
#                                  Полное наименование Сокращенное наименование  \
# 0  Государственное бюджетное учреждение Ростовско...        ГБУ РО «СШОР № 1»
# 1  Государственное бюджетное учреждение Ростовско...        ГБУ РО «СШОР № 3»
# 2  Государственное бюджетное учреждение Ростовско...        ГБУ РО «СШОР № 5»
# 3  Государственное бюджетное учреждение Ростовско...        ГБУ РО «СШОР № 6»
# 4  Государственное бюджетное учреждение Ростовско...        ГБУ РО «СШОР № 8»
#
#                                                Адрес          Телефон  \
# 0    344113, г. Ростов-на-Дону, ул. Шеболдаева, 97/2  (863) 219-84-27
# 1  347922 , Ростовская область , г. Таганрог, ул....   (8634)38-39-17
# 2       344002, г. Ростов-на-Дону, ул. Пойменная, 2а   (863)282-83-65
# 3  344000, г. Ростов-на-Дону, Пр.Коммунистический...   (863)210-35-69
# 4  344029, г. Ростов-на-Дону, ул.1-й Конной Армии...   (863)242-29-77
#
#               Факс                    Сайт  \
# 0  (863) 219-84-27            schor1-rr.ru
# 1   (8634)36-10-91            www.tcs-3.ru
# 2   (863)282-83-65  www.rowingdon.narod.ru
# 3   (863)210-35-69    www.sportschool-6.ru
# 4   (863)242-29-77         www.sdushor8.ru
#
#                            Наименование видов спорта
# 0                                       Дзюдо, самбо
# 1  Гребля на байдарках и каноэ, дзюдо, парусный с...
# 2  Гребной спорт (академическая гребля), гребля н...
# 3                Фигурное катание на коньках, хоккей
# 4  Гребной спорт (академическая гребля), легкая а...

# %%
import random
df['Коэффициент премиальности тренеров'] = random.randint(0,23)
df.head()
# Out:
#                                  Полное наименование Сокращенное наименование  \
# 0  Государственное бюджетное учреждение Ростовско...        ГБУ РО «СШОР № 1»
# 1  Государственное бюджетное учреждение Ростовско...        ГБУ РО «СШОР № 3»
# 2  Государственное бюджетное учреждение Ростовско...        ГБУ РО «СШОР № 5»
# 3  Государственное бюджетное учреждение Ростовско...        ГБУ РО «СШОР № 6»
# 4  Государственное бюджетное учреждение Ростовско...        ГБУ РО «СШОР № 8»
#
#                                                Адрес          Телефон  \
# 0    344113, г. Ростов-на-Дону, ул. Шеболдаева, 97/2  (863) 219-84-27
# 1  347922 , Ростовская область , г. Таганрог, ул....   (8634)38-39-17
# 2       344002, г. Ростов-на-Дону, ул. Пойменная, 2а   (863)282-83-65
# 3  344000, г. Ростов-на-Дону, Пр.Коммунистический...   (863)210-35-69
# 4  344029, г. Ростов-на-Дону, ул.1-й Конной Армии...   (863)242-29-77
#
#               Факс                    Сайт  \
# 0  (863) 219-84-27            schor1-rr.ru
# 1   (8634)36-10-91            www.tcs-3.ru
# 2   (863)282-83-65  www.rowingdon.narod.ru
# 3   (863)210-35-69    www.sportschool-6.ru
# 4   (863)242-29-77         www.sdushor8.ru
#
#                            Наименование видов спорта  \
# 0                                       Дзюдо, самбо
# 1  Гребля на байдарках и каноэ, дзюдо, парусный с...
# 2  Гребной спорт (академическая гребля), гребля н...
# 3                Фигурное катание на коньках, хоккей
# 4  Гребной спорт (академическая гребля), легкая а...
#
#    Коэффициент премиальности тренеров
# 0                                  22
# 1                                  22
# 2                                  22
# 3                                  22
# 4                                  22

# %%
import matplotlib
df['Коэффициент премиальности тренеров'].plot()

# %% [markdown]
# ссылки на сайты стат данных
#
#
# https://data.gov.ru/taxonomy/term/9/datasets
#
# http://sophist.hse.ru/rstat/

# %% [markdown]
# можно взять данные из задач
#
# https://github.com/hightemp/docNN/blob/b96f37611dd3ebdd5b2269e04582683af74b8340/articles/%D0%9F%D1%80%D0%B8%D0%BC%D0%B5%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B0%D1%88%D0%B8%D0%BD%D0%BD%D0%BE%D0%B3%D0%BE%20%D0%BE%D0%B1%D1%83%D1%87%D0%B5%D0%BD%D0%B8%D1%8F%20%D0%B8%20Data%20Science%20%D0%B2%20%D0%BF%D1%80%D0%BE%D0%BC%D1%8B%D1%88%D0%BB%D0%B5%D0%BD%D0%BD%D0%BE%D1%81%D1%82%D0%B8.md
